# %%
import pandas as pd
import matplotlib as plt
import numpy

# %%
merged_keys_df = pd.read_csv("../Resources/Clean_Main_Merged_data")
merged_keys_df
# Out:
#         Unnamed: 0  Key MusicalKey  valence  year  acousticness  \
# 0                0    0          C    0.406  1921        0.9960
# 1                1    0          C    0.403  1921        0.9920
# 2                2    0          C    0.651  1921        0.9920
# 3                3    0          C    0.275  1921        0.5970
# 4                4    0          C    0.574  1921        0.9950
# ...            ...  ...        ...      ...   ...           ...
# 170648      170648   11          B    0.394  2020        0.6960
# 170649      170649   11          B    0.514  2020        0.1290
# 170650      170650   11          B    0.632  2020        0.3550
# 170651      170651   11          B    0.547  2020        0.0851
# 170652      170652   11          B    0.210  2020        0.9680
#
#                                                   artists  danceability  \
# 0                                      ['John McCormack']         0.518
# ...

# %%
merged_keys_df.loc[merged_keys_df["popularity"]>=80].count()
# Out:
# Unnamed: 0          688
# Key                 688
# MusicalKey          688
# valence             688
# year                688
# acousticness        688
# artists             688
# danceability        688
# duration_ms         688
# energy              688
# explicit            688
# id                  688
# instrumentalness    688
# liveness            688
# loudness            688
# mode                688
# name                688
# popularity          688
# release_date        688
# speechiness         688
# tempo               688
# dtype: int64

# %%
top80 = merged_keys_df.loc[merged_keys_df["popularity"]>=80]
top80
# Out:
#         Unnamed: 0  Key MusicalKey  valence  year  acousticness  \
# 1233          1233    0          C    0.663  1969        0.2010
# 1445          1445    0          C    0.789  1977        0.0644
# 1619          1619    0          C    0.875  1983        0.2250
# 1687          1687    0          C    0.795  1986        0.0778
# 1688          1688    0          C    0.812  1986        0.0663
# ...            ...  ...        ...      ...   ...           ...
# 164504      164504   11          B    0.650  2020        0.0816
# 166681      166681   11          B    0.776  2020        0.2890
# 169707      169707   11          B    0.804  2020        0.4960
# 169720      169720   11          B    0.400  2020        0.1930
# 169722      169722   11          B    0.444  2020        0.1500
#
#                                                artists  danceability  \
# 1233                  ['Creedence Clearwater Revival']         0.640
# ...

# %%
max_loudness = top80["loud"]

# %%
top80.to_csv("../Resources/Top80song.csv")
